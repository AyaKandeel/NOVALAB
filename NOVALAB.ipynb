# %%
# %%!
# pip install --trusted host pypi.org ipython-sql
# Out:
# ['Collecting pypi.org',
#  '  Downloading pypi.org-0.0.0.tar.gz (583 bytes)',
#  'Collecting ipython-sql',
#  '  Downloading ipython_sql-0.4.0-py3-none-any.whl (19 kB)',
#  'Requirement already satisfied: sqlalchemy>=0.6.7 in c:\\programdata\\anaconda3\\lib\\site-packages (from ipython-sql) (1.3.18)',
#  'Requirement already satisfied: ipython-genutils>=0.1.0 in c:\\programdata\\anaconda3\\lib\\site-packages (from ipython-sql) (0.2.0)',
#  'Requirement already satisfied: ipython>=1.0 in c:\\programdata\\anaconda3\\lib\\site-packages (from ipython-sql) (7.16.1)',
#  'Collecting prettytable<1',
#  '  Downloading prettytable-0.7.2.tar.bz2 (21 kB)',
#  'Requirement already satisfied: six in c:\\programdata\\anaconda3\\lib\\site-packages (from ipython-sql) (1.15.0)',
#  'Collecting sqlparse',
#  '  Downloading sqlparse-0.3.1-py2.py3-none-any.whl (40 kB)',
# ...

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite://

# %%
# %%sql
# CREATE TABLE NOVAXLAB (name varchar(50),country varchar(20),ID varchar(20),date of birth varchar(20),phone number(50));
# INSERT INTO NOVAXLAB VALUES('sila','egypt','','','');
# INSERT INTO NOVAXLAB VALUES('ema','japan','','','');
# INSERT INTO NOVAXLAB VALUES('nour','italy','','','');
# INSERT INTO NOVAXLAB VALUES('nada','china','','','');
# INSERT INTO NOVAXLAB VALUES('doha','india','','','');
# INSERT INTO NOVAXLAB VALUES('morad','egypt','','','');
# INSERT INTO NOVAXLAB VALUES('mohammed','egypt','','','');
# INSERT INTO NOVAXLAB VALUES('khaled','USA','','','');
# INSERT INTO NOVAXLAB VALUES('sara','japan','','','');
# INSERT INTO NOVAXLAB VALUES('mariam','china','','','');
# INSERT INTO NOVAXLAB VALUES('ahmed','japan','','','');
# INSERT INTO NOVAXLAB VALUES('yazan','egypt','','','');
# INSERT INTO NOVAXLAB VALUES('mustafa','japan','','','');
# INSERT INTO NOVAXLAB VALUES('aml','china','','','');
# INSERT INTO NOVAXLAB VALUES('kamal','italy','','','');
# INSERT INTO NOVAXLAB VALUES('aysel','egypt','','','');
# INSERT INTO NOVAXLAB VALUES('malik','japan','','','');
# INSERT INTO NOVAXLAB VALUES('osama','egypt','','','');
# INSERT INTO NOVAXLAB VALUES('mazen','USA','','','');
# INSERT INTO NOVAXLAB VALUES('aylen','egypt','','','');
# SELECT * FROM NOVAXLAB ;
# Out:
#  * sqlite://
# (sqlite3.OperationalError) table NOVAXLAB already exists
# [SQL: CREATE TABLE NOVAXLAB (name varchar(50),country varchar(20),ID varchar(20),date of birth varchar(20),phone number(50));]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# %%sql
# CREATE TABLE NOVALAB (name varchar(50),country varchar(20),ID varchar(20),date of birth varchar(20),phone number(50));
# INSERT INTO NOVALAB VALUES('sila','egypt','','','');
# INSERT INTO NOVALAB VALUES('ema','japan','','','');
# INSERT INTO NOVALAB VALUES('nour','italy','','','');
# INSERT INTO NOVALAB VALUES('nada','china','','','');
# INSERT INTO NOVALAB VALUES('doha','india','','','');
# INSERT INTO NOVALAB VALUES('morad','egypt','','','');
# INSERT INTO NOVALAB VALUES('mohammed','egypt','','','');
# INSERT INTO NOVALAB VALUES('khaled','USA','','','');
# INSERT INTO NOVALAB VALUES('sara','japan','','','');
# INSERT INTO NOVALAB VALUES('mariam','china','','','');
# INSERT INTO NOVALAB VALUES('ahmed','japan','','','');
# INSERT INTO NOVALAB VALUES('yazan','egypt','','','');
# INSERT INTO NOVALAB VALUES('mustafa','japan','','','');
# INSERT INTO NOVALAB VALUES('aml','china','','','');
# INSERT INTO NOVALAB VALUES('kamal','italy','','','');
# INSERT INTO NOVALAB VALUES('aysel','egypt','','','');
# INSERT INTO NOVALAB VALUES('malik','japan','','','');
# INSERT INTO NOVALAB VALUES('osama','egypt','','','');
# INSERT INTO NOVALAB VALUES('mazen','USA','','','');
# INSERT INTO NOVALAB VALUES('aylen','egypt','','','');
# SELECT * FROM NOVALAB ;
# Out:
#  * sqlite://
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# Done.
# [('sila', 'egypt', '', '', ''),
#  ('ema', 'japan', '', '', ''),
#  ('nour', 'italy', '', '', ''),
#  ('nada', 'china', '', '', ''),
#  ('doha', 'india', '', '', ''),
#  ('morad', 'egypt', '', '', ''),
#  ('mohammed', 'egypt', '', '', ''),
#  ('khaled', 'USA', '', '', ''),
#  ('sara', 'japan', '', '', ''),
#  ('mariam', 'china', '', '', ''),
#  ('ahmed', 'japan', '', '', ''),
#  ('yazan', 'egypt', '', '', ''),
#  ('mustafa', 'japan', '', '', ''),
#  ('aml', 'china', '', '', ''),
#  ('kamal', 'italy', '', '', ''),
#  ('aysel', 'egypt', '', '', ''),
# ...
